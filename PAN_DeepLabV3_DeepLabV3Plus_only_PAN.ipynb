# %%
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# !pip install -q torchsummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/qubvel/segmentation_models.pytorch
#   Cloning https://github.com/qubvel/segmentation_models.pytorch to /tmp/pip-req-build-4q24ryoi
#   Running command git clone --filter=blob:none --quiet https://github.com/qubvel/segmentation_models.pytorch /tmp/pip-req-build-4q24ryoi
#   Resolved https://github.com/qubvel/segmentation_models.pytorch to commit e7cbea0bbd546167b9d1757b2cfeca3fbe26a33e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting efficientnet-pytorch==0.7.1
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch==0.3.2) (0.15.1+cu118)
# Collecting timm==0.6.13
#   Downloading timm-0.6.13-py3-none-any.whl (549 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 12.1 MB/s eta 0:00:00
# Collecting pretrainedmodels==0.7.4
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch==0.3.2) (4.65.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch==0.3.2) (8.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (2.0.0+cu118)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.6.13->segmentation-models-pytorch==0.3.2) (6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch==0.3.2) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch==0.3.2) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (3.12.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (4.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (3.25.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.6.13->segmentation-models-pytorch==0.3.2) (23.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.6.13->segmentation-models-pytorch==0.3.2) (2023.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.3.2) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch==0.3.2) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch==0.3.2) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch==0.3.2) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch==0.3.2) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.2) (1.3.0)
# Building wheels for collected packages: segmentation-models-pytorch, efficientnet-pytorch, pretrainedmodels
#   Building wheel for segmentation-models-pytorch (pyproject.toml) ... done
#   Created wheel for segmentation-models-pytorch: filename=segmentation_models_pytorch-0.3.2-py3-none-any.whl size=106755 sha256=b24c217522ab36ce404beefe429290014aa984681dc2abfde540327ed4857079
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z5p6ar74/wheels/1a/49/5f/858bc2741660e381e83f1d8b297edc4d9f0561f29becaee577
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16444 sha256=e265f35d1284e3c30d8f5aefff49161af5765b124378cfddacdc292bda2de36c
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60962 sha256=1f10c3125d034c96929ed04c0b127a6e98b0542d37adcfb5cc39d3743df51448
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built segmentation-models-pytorch efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, huggingface-hub, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.7.1 huggingface-hub-0.14.1 munch-2.5.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.3.2 timm-0.6.13

# %% [markdown]
# https://github.com/qubvel/segmentation_models.pytorch

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torchvision
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
from torchsummary import summary

import segmentation_models_pytorch as smp

from PIL import Image
import albumentations, cv2, time, os
from tqdm.notebook import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Create Dataset**

# %% [markdown]
# Aerial Semantic Segmentation Drone Dataset from https://www.kaggle.com/datasets/bulentsiyah/semantic-drone-dataset - 23 different classes

# %%
# !unzip /content/drive/MyDrive/segmentation_ml/segmentation_with_transformer/dataset.zip
# Out:
# Archive:  /content/drive/MyDrive/segmentation_ml/segmentation_with_transformer/dataset.zip
#   inflating: semantic_drone_dataset/label_images_semantic/000.png
#   inflating: semantic_drone_dataset/label_images_semantic/001.png
#   inflating: semantic_drone_dataset/label_images_semantic/002.png
#   inflating: semantic_drone_dataset/label_images_semantic/003.png
#   inflating: semantic_drone_dataset/label_images_semantic/004.png
#   inflating: semantic_drone_dataset/label_images_semantic/005.png
#   inflating: semantic_drone_dataset/label_images_semantic/006.png
#   inflating: semantic_drone_dataset/label_images_semantic/008.png
#   inflating: semantic_drone_dataset/label_images_semantic/011.png
#   inflating: semantic_drone_dataset/label_images_semantic/013.png
#   inflating: semantic_drone_dataset/label_images_semantic/014.png
#   inflating: semantic_drone_dataset/label_images_semantic/015.png
#   inflating: semantic_drone_dataset/label_images_semantic/016.png
#   inflating: semantic_drone_dataset/label_images_semantic/018.png
#   inflating: semantic_drone_dataset/label_images_semantic/019.png
#   inflating: semantic_drone_dataset/label_images_semantic/021.png
#   inflating: semantic_drone_dataset/label_images_semantic/022.png
#   inflating: semantic_drone_dataset/label_images_semantic/023.png
#   inflating: semantic_drone_dataset/label_images_semantic/026.png
#   inflating: semantic_drone_dataset/label_images_semantic/028.png
#   inflating: semantic_drone_dataset/label_images_semantic/031.png
#   inflating: semantic_drone_dataset/label_images_semantic/035.png
#   inflating: semantic_drone_dataset/label_images_semantic/038.png
#   inflating: semantic_drone_dataset/label_images_semantic/040.png
#   inflating: semantic_drone_dataset/label_images_semantic/041.png
#   inflating: semantic_drone_dataset/label_images_semantic/042.png
#   inflating: semantic_drone_dataset/label_images_semantic/043.png
#   inflating: semantic_drone_dataset/label_images_semantic/044.png
#   inflating: semantic_drone_dataset/label_images_semantic/045.png
#   inflating: semantic_drone_dataset/label_images_semantic/047.png
#   inflating: semantic_drone_dataset/label_images_semantic/049.png
#   inflating: semantic_drone_dataset/label_images_semantic/051.png
#   inflating: semantic_drone_dataset/label_images_semantic/052.png
#   inflating: semantic_drone_dataset/label_images_semantic/053.png
#   inflating: semantic_drone_dataset/label_images_semantic/055.png
#   inflating: semantic_drone_dataset/label_images_semantic/056.png
#   inflating: semantic_drone_dataset/label_images_semantic/057.png
#   inflating: semantic_drone_dataset/label_images_semantic/058.png
#   inflating: semantic_drone_dataset/label_images_semantic/059.png
#   inflating: semantic_drone_dataset/label_images_semantic/060.png
#   inflating: semantic_drone_dataset/label_images_semantic/062.png
#   inflating: semantic_drone_dataset/label_images_semantic/063.png
#   inflating: semantic_drone_dataset/label_images_semantic/065.png
#   inflating: semantic_drone_dataset/label_images_semantic/068.png
#   inflating: semantic_drone_dataset/label_images_semantic/070.png
#   inflating: semantic_drone_dataset/label_images_semantic/071.png
#   inflating: semantic_drone_dataset/label_images_semantic/073.png
#   inflating: semantic_drone_dataset/label_images_semantic/074.png
#   inflating: semantic_drone_dataset/label_images_semantic/075.png
#   inflating: semantic_drone_dataset/label_images_semantic/077.png
#   inflating: semantic_drone_dataset/label_images_semantic/078.png
#   inflating: semantic_drone_dataset/label_images_semantic/079.png
#   inflating: semantic_drone_dataset/label_images_semantic/080.png
#   inflating: semantic_drone_dataset/label_images_semantic/081.png
#   inflating: semantic_drone_dataset/label_images_semantic/083.png
#   inflating: semantic_drone_dataset/label_images_semantic/086.png
#   inflating: semantic_drone_dataset/label_images_semantic/088.png
#   inflating: semantic_drone_dataset/label_images_semantic/089.png
#   inflating: semantic_drone_dataset/label_images_semantic/092.png
#   inflating: semantic_drone_dataset/label_images_semantic/095.png
#   inflating: semantic_drone_dataset/label_images_semantic/098.png
#   inflating: semantic_drone_dataset/label_images_semantic/099.png
#   inflating: semantic_drone_dataset/label_images_semantic/100.png
#   inflating: semantic_drone_dataset/label_images_semantic/101.png
#   inflating: semantic_drone_dataset/label_images_semantic/102.png
#   inflating: semantic_drone_dataset/label_images_semantic/103.png
#   inflating: semantic_drone_dataset/label_images_semantic/104.png
#   inflating: semantic_drone_dataset/label_images_semantic/106.png
#   inflating: semantic_drone_dataset/label_images_semantic/107.png
#   inflating: semantic_drone_dataset/label_images_semantic/109.png
#   inflating: semantic_drone_dataset/label_images_semantic/110.png
#   inflating: semantic_drone_dataset/label_images_semantic/111.png
#   inflating: semantic_drone_dataset/label_images_semantic/112.png
#   inflating: semantic_drone_dataset/label_images_semantic/113.png
#   inflating: semantic_drone_dataset/label_images_semantic/116.png
#   inflating: semantic_drone_dataset/label_images_semantic/117.png
#   inflating: semantic_drone_dataset/label_images_semantic/118.png
#   inflating: semantic_drone_dataset/label_images_semantic/119.png
#   inflating: semantic_drone_dataset/label_images_semantic/120.png
#   inflating: semantic_drone_dataset/label_images_semantic/121.png
#   inflating: semantic_drone_dataset/label_images_semantic/122.png
#   inflating: semantic_drone_dataset/label_images_semantic/123.png
#   inflating: semantic_drone_dataset/label_images_semantic/124.png
#   inflating: semantic_drone_dataset/label_images_semantic/126.png
#   inflating: semantic_drone_dataset/label_images_semantic/128.png
#   inflating: semantic_drone_dataset/label_images_semantic/130.png
#   inflating: semantic_drone_dataset/label_images_semantic/133.png
#   inflating: semantic_drone_dataset/label_images_semantic/134.png
#   inflating: semantic_drone_dataset/label_images_semantic/135.png
#   inflating: semantic_drone_dataset/label_images_semantic/136.png
#   inflating: semantic_drone_dataset/label_images_semantic/137.png
#   inflating: semantic_drone_dataset/label_images_semantic/138.png
#   inflating: semantic_drone_dataset/label_images_semantic/139.png
#   inflating: semantic_drone_dataset/label_images_semantic/140.png
#   inflating: semantic_drone_dataset/label_images_semantic/141.png
#   inflating: semantic_drone_dataset/label_images_semantic/145.png
#   inflating: semantic_drone_dataset/label_images_semantic/146.png
#   inflating: semantic_drone_dataset/label_images_semantic/147.png
#   inflating: semantic_drone_dataset/label_images_semantic/148.png
#   inflating: semantic_drone_dataset/label_images_semantic/149.png
#   inflating: semantic_drone_dataset/label_images_semantic/150.png
#   inflating: semantic_drone_dataset/label_images_semantic/153.png
#   inflating: semantic_drone_dataset/label_images_semantic/154.png
#   inflating: semantic_drone_dataset/label_images_semantic/155.png
#   inflating: semantic_drone_dataset/label_images_semantic/156.png
#   inflating: semantic_drone_dataset/label_images_semantic/157.png
#   inflating: semantic_drone_dataset/label_images_semantic/158.png
#   inflating: semantic_drone_dataset/label_images_semantic/159.png
#   inflating: semantic_drone_dataset/label_images_semantic/160.png
#   inflating: semantic_drone_dataset/label_images_semantic/161.png
#   inflating: semantic_drone_dataset/label_images_semantic/162.png
#   inflating: semantic_drone_dataset/label_images_semantic/163.png
#   inflating: semantic_drone_dataset/label_images_semantic/164.png
#   inflating: semantic_drone_dataset/label_images_semantic/165.png
#   inflating: semantic_drone_dataset/label_images_semantic/166.png
#   inflating: semantic_drone_dataset/label_images_semantic/167.png
#   inflating: semantic_drone_dataset/label_images_semantic/170.png
#   inflating: semantic_drone_dataset/label_images_semantic/171.png
#   inflating: semantic_drone_dataset/label_images_semantic/172.png
#   inflating: semantic_drone_dataset/label_images_semantic/173.png
#   inflating: semantic_drone_dataset/label_images_semantic/174.png
#   inflating: semantic_drone_dataset/label_images_semantic/175.png
#   inflating: semantic_drone_dataset/label_images_semantic/176.png
#   inflating: semantic_drone_dataset/label_images_semantic/177.png
#   inflating: semantic_drone_dataset/label_images_semantic/178.png
#   inflating: semantic_drone_dataset/label_images_semantic/179.png
#   inflating: semantic_drone_dataset/label_images_semantic/180.png
#   inflating: semantic_drone_dataset/label_images_semantic/181.png
#   inflating: semantic_drone_dataset/label_images_semantic/182.png
#   inflating: semantic_drone_dataset/label_images_semantic/185.png
#   inflating: semantic_drone_dataset/label_images_semantic/186.png
#   inflating: semantic_drone_dataset/label_images_semantic/188.png
#   inflating: semantic_drone_dataset/label_images_semantic/190.png
#   inflating: semantic_drone_dataset/label_images_semantic/192.png
#   inflating: semantic_drone_dataset/label_images_semantic/193.png
#   inflating: semantic_drone_dataset/label_images_semantic/194.png
#   inflating: semantic_drone_dataset/label_images_semantic/195.png
#   inflating: semantic_drone_dataset/label_images_semantic/198.png
#   inflating: semantic_drone_dataset/label_images_semantic/199.png
#   inflating: semantic_drone_dataset/label_images_semantic/200.png
#   inflating: semantic_drone_dataset/label_images_semantic/202.png
#   inflating: semantic_drone_dataset/label_images_semantic/204.png
#   inflating: semantic_drone_dataset/label_images_semantic/206.png
#   inflating: semantic_drone_dataset/label_images_semantic/207.png
#   inflating: semantic_drone_dataset/label_images_semantic/208.png
#   inflating: semantic_drone_dataset/label_images_semantic/209.png
#   inflating: semantic_drone_dataset/label_images_semantic/213.png
#   inflating: semantic_drone_dataset/label_images_semantic/214.png
#   inflating: semantic_drone_dataset/label_images_semantic/215.png
#   inflating: semantic_drone_dataset/label_images_semantic/216.png
#   inflating: semantic_drone_dataset/label_images_semantic/217.png
#   inflating: semantic_drone_dataset/label_images_semantic/219.png
#   inflating: semantic_drone_dataset/label_images_semantic/220.png
#   inflating: semantic_drone_dataset/label_images_semantic/221.png
#   inflating: semantic_drone_dataset/label_images_semantic/222.png
#   inflating: semantic_drone_dataset/label_images_semantic/223.png
#   inflating: semantic_drone_dataset/label_images_semantic/225.png
#   inflating: semantic_drone_dataset/label_images_semantic/226.png
#   inflating: semantic_drone_dataset/label_images_semantic/228.png
#   inflating: semantic_drone_dataset/label_images_semantic/229.png
#   inflating: semantic_drone_dataset/label_images_semantic/230.png
#   inflating: semantic_drone_dataset/label_images_semantic/232.png
#   inflating: semantic_drone_dataset/label_images_semantic/233.png
#   inflating: semantic_drone_dataset/label_images_semantic/234.png
#   inflating: semantic_drone_dataset/label_images_semantic/235.png
#   inflating: semantic_drone_dataset/label_images_semantic/236.png
#   inflating: semantic_drone_dataset/label_images_semantic/237.png
#   inflating: semantic_drone_dataset/label_images_semantic/238.png
#   inflating: semantic_drone_dataset/label_images_semantic/239.png
#   inflating: semantic_drone_dataset/label_images_semantic/240.png
#   inflating: semantic_drone_dataset/label_images_semantic/243.png
#   inflating: semantic_drone_dataset/label_images_semantic/244.png
#   inflating: semantic_drone_dataset/label_images_semantic/246.png
#   inflating: semantic_drone_dataset/label_images_semantic/248.png
#   inflating: semantic_drone_dataset/label_images_semantic/250.png
#   inflating: semantic_drone_dataset/label_images_semantic/251.png
#   inflating: semantic_drone_dataset/label_images_semantic/252.png
#   inflating: semantic_drone_dataset/label_images_semantic/255.png
#   inflating: semantic_drone_dataset/label_images_semantic/257.png
#   inflating: semantic_drone_dataset/label_images_semantic/258.png
#   inflating: semantic_drone_dataset/label_images_semantic/259.png
#   inflating: semantic_drone_dataset/label_images_semantic/260.png
#   inflating: semantic_drone_dataset/label_images_semantic/261.png
#   inflating: semantic_drone_dataset/label_images_semantic/262.png
#   inflating: semantic_drone_dataset/label_images_semantic/263.png
#   inflating: semantic_drone_dataset/label_images_semantic/265.png
#   inflating: semantic_drone_dataset/label_images_semantic/266.png
#   inflating: semantic_drone_dataset/label_images_semantic/271.png
#   inflating: semantic_drone_dataset/label_images_semantic/272.png
#   inflating: semantic_drone_dataset/label_images_semantic/273.png
#   inflating: semantic_drone_dataset/label_images_semantic/275.png
#   inflating: semantic_drone_dataset/label_images_semantic/276.png
#   inflating: semantic_drone_dataset/label_images_semantic/277.png
#   inflating: semantic_drone_dataset/label_images_semantic/281.png
#   inflating: semantic_drone_dataset/label_images_semantic/283.png
#   inflating: semantic_drone_dataset/label_images_semantic/287.png
#   inflating: semantic_drone_dataset/label_images_semantic/288.png
#   inflating: semantic_drone_dataset/label_images_semantic/289.png
#   inflating: semantic_drone_dataset/label_images_semantic/290.png
#   inflating: semantic_drone_dataset/label_images_semantic/292.png
#   inflating: semantic_drone_dataset/label_images_semantic/294.png
#   inflating: semantic_drone_dataset/label_images_semantic/295.png
#   inflating: semantic_drone_dataset/label_images_semantic/296.png
#   inflating: semantic_drone_dataset/label_images_semantic/298.png
#   inflating: semantic_drone_dataset/label_images_semantic/299.png
#   inflating: semantic_drone_dataset/label_images_semantic/301.png
#   inflating: semantic_drone_dataset/label_images_semantic/302.png
#   inflating: semantic_drone_dataset/label_images_semantic/303.png
#   inflating: semantic_drone_dataset/label_images_semantic/304.png
#   inflating: semantic_drone_dataset/label_images_semantic/305.png
#   inflating: semantic_drone_dataset/label_images_semantic/306.png
#   inflating: semantic_drone_dataset/label_images_semantic/309.png
#   inflating: semantic_drone_dataset/label_images_semantic/310.png
#   inflating: semantic_drone_dataset/label_images_semantic/311.png
#   inflating: semantic_drone_dataset/label_images_semantic/312.png
#   inflating: semantic_drone_dataset/label_images_semantic/313.png
#   inflating: semantic_drone_dataset/label_images_semantic/314.png
#   inflating: semantic_drone_dataset/label_images_semantic/316.png
#   inflating: semantic_drone_dataset/label_images_semantic/318.png
#   inflating: semantic_drone_dataset/label_images_semantic/320.png
#   inflating: semantic_drone_dataset/label_images_semantic/321.png
#   inflating: semantic_drone_dataset/label_images_semantic/322.png
#   inflating: semantic_drone_dataset/label_images_semantic/323.png
#   inflating: semantic_drone_dataset/label_images_semantic/324.png
#   inflating: semantic_drone_dataset/label_images_semantic/325.png
#   inflating: semantic_drone_dataset/label_images_semantic/326.png
#   inflating: semantic_drone_dataset/label_images_semantic/329.png
#   inflating: semantic_drone_dataset/label_images_semantic/330.png
#   inflating: semantic_drone_dataset/label_images_semantic/331.png
#   inflating: semantic_drone_dataset/label_images_semantic/332.png
#   inflating: semantic_drone_dataset/label_images_semantic/334.png
#   inflating: semantic_drone_dataset/label_images_semantic/335.png
#   inflating: semantic_drone_dataset/label_images_semantic/338.png
#   inflating: semantic_drone_dataset/label_images_semantic/339.png
#   inflating: semantic_drone_dataset/label_images_semantic/341.png
#   inflating: semantic_drone_dataset/label_images_semantic/342.png
#   inflating: semantic_drone_dataset/label_images_semantic/344.png
#   inflating: semantic_drone_dataset/label_images_semantic/345.png
#   inflating: semantic_drone_dataset/label_images_semantic/346.png
#   inflating: semantic_drone_dataset/label_images_semantic/347.png
#   inflating: semantic_drone_dataset/label_images_semantic/348.png
#   inflating: semantic_drone_dataset/label_images_semantic/349.png
#   inflating: semantic_drone_dataset/label_images_semantic/351.png
#   inflating: semantic_drone_dataset/label_images_semantic/355.png
#   inflating: semantic_drone_dataset/label_images_semantic/356.png
#   inflating: semantic_drone_dataset/label_images_semantic/361.png
#   inflating: semantic_drone_dataset/label_images_semantic/363.png
#   inflating: semantic_drone_dataset/label_images_semantic/366.png
#   inflating: semantic_drone_dataset/label_images_semantic/367.png
#   inflating: semantic_drone_dataset/label_images_semantic/372.png
#   inflating: semantic_drone_dataset/label_images_semantic/373.png
#   inflating: semantic_drone_dataset/label_images_semantic/375.png
#   inflating: semantic_drone_dataset/label_images_semantic/376.png
#   inflating: semantic_drone_dataset/label_images_semantic/378.png
#   inflating: semantic_drone_dataset/label_images_semantic/380.png
#   inflating: semantic_drone_dataset/label_images_semantic/381.png
#   inflating: semantic_drone_dataset/label_images_semantic/382.png
#   inflating: semantic_drone_dataset/label_images_semantic/383.png
#   inflating: semantic_drone_dataset/label_images_semantic/385.png
#   inflating: semantic_drone_dataset/label_images_semantic/386.png
#   inflating: semantic_drone_dataset/label_images_semantic/388.png
#   inflating: semantic_drone_dataset/label_images_semantic/467.png
#   inflating: semantic_drone_dataset/label_images_semantic/470.png
#   inflating: semantic_drone_dataset/label_images_semantic/472.png
#   inflating: semantic_drone_dataset/label_images_semantic/473.png
#   inflating: semantic_drone_dataset/label_images_semantic/474.png
#   inflating: semantic_drone_dataset/label_images_semantic/475.png
#   inflating: semantic_drone_dataset/label_images_semantic/476.png
#   inflating: semantic_drone_dataset/label_images_semantic/478.png
#   inflating: semantic_drone_dataset/label_images_semantic/479.png
#   inflating: semantic_drone_dataset/label_images_semantic/480.png
#   inflating: semantic_drone_dataset/label_images_semantic/484.png
#   inflating: semantic_drone_dataset/label_images_semantic/485.png
#   inflating: semantic_drone_dataset/label_images_semantic/488.png
#   inflating: semantic_drone_dataset/label_images_semantic/489.png
#   inflating: semantic_drone_dataset/label_images_semantic/491.png
#   inflating: semantic_drone_dataset/label_images_semantic/493.png
#   inflating: semantic_drone_dataset/label_images_semantic/494.png
#   inflating: semantic_drone_dataset/label_images_semantic/497.png
#   inflating: semantic_drone_dataset/label_images_semantic/498.png
#   inflating: semantic_drone_dataset/label_images_semantic/499.png
#   inflating: semantic_drone_dataset/label_images_semantic/500.png
#   inflating: semantic_drone_dataset/label_images_semantic/501.png
#   inflating: semantic_drone_dataset/label_images_semantic/502.png
#   inflating: semantic_drone_dataset/label_images_semantic/507.png
#   inflating: semantic_drone_dataset/label_images_semantic/508.png
#   inflating: semantic_drone_dataset/label_images_semantic/509.png
#   inflating: semantic_drone_dataset/label_images_semantic/510.png
#   inflating: semantic_drone_dataset/label_images_semantic/512.png
#   inflating: semantic_drone_dataset/label_images_semantic/513.png
#   inflating: semantic_drone_dataset/label_images_semantic/514.png
#   inflating: semantic_drone_dataset/label_images_semantic/515.png
#   inflating: semantic_drone_dataset/label_images_semantic/517.png
#   inflating: semantic_drone_dataset/label_images_semantic/518.png
#   inflating: semantic_drone_dataset/label_images_semantic/521.png
#   inflating: semantic_drone_dataset/label_images_semantic/524.png
#   inflating: semantic_drone_dataset/label_images_semantic/525.png
#   inflating: semantic_drone_dataset/label_images_semantic/526.png
#   inflating: semantic_drone_dataset/label_images_semantic/529.png
#   inflating: semantic_drone_dataset/label_images_semantic/530.png
#   inflating: semantic_drone_dataset/label_images_semantic/531.png
#   inflating: semantic_drone_dataset/label_images_semantic/532.png
#   inflating: semantic_drone_dataset/label_images_semantic/533.png
#   inflating: semantic_drone_dataset/label_images_semantic/535.png
#   inflating: semantic_drone_dataset/label_images_semantic/536.png
#   inflating: semantic_drone_dataset/label_images_semantic/537.png
#   inflating: semantic_drone_dataset/label_images_semantic/538.png
#   inflating: semantic_drone_dataset/label_images_semantic/540.png
#   inflating: semantic_drone_dataset/label_images_semantic/543.png
#   inflating: semantic_drone_dataset/label_images_semantic/544.png
#   inflating: semantic_drone_dataset/label_images_semantic/545.png
#   inflating: semantic_drone_dataset/label_images_semantic/549.png
#   inflating: semantic_drone_dataset/label_images_semantic/551.png
#   inflating: semantic_drone_dataset/original_images/535.jpg
#   inflating: semantic_drone_dataset/original_images/536.jpg
#   inflating: semantic_drone_dataset/original_images/537.jpg
#   inflating: semantic_drone_dataset/original_images/538.jpg
#   inflating: semantic_drone_dataset/original_images/540.jpg
#   inflating: semantic_drone_dataset/original_images/543.jpg
#   inflating: semantic_drone_dataset/original_images/544.jpg
#   inflating: semantic_drone_dataset/original_images/545.jpg
#   inflating: semantic_drone_dataset/original_images/549.jpg
#   inflating: semantic_drone_dataset/original_images/551.jpg
#   inflating: semantic_drone_dataset/original_images/554.jpg
#   inflating: semantic_drone_dataset/original_images/556.jpg
#   inflating: semantic_drone_dataset/original_images/558.jpg
#   inflating: semantic_drone_dataset/original_images/559.jpg
#   inflating: semantic_drone_dataset/original_images/560.jpg
#   inflating: semantic_drone_dataset/original_images/561.jpg
#   inflating: semantic_drone_dataset/original_images/563.jpg
#   inflating: semantic_drone_dataset/original_images/564.jpg
#   inflating: semantic_drone_dataset/original_images/565.jpg
#   inflating: semantic_drone_dataset/original_images/566.jpg
#   inflating: semantic_drone_dataset/original_images/567.jpg
#   inflating: semantic_drone_dataset/original_images/568.jpg
#   inflating: semantic_drone_dataset/original_images/569.jpg
#   inflating: semantic_drone_dataset/original_images/570.jpg
#   inflating: semantic_drone_dataset/original_images/572.jpg
#   inflating: semantic_drone_dataset/original_images/573.jpg
#   inflating: semantic_drone_dataset/original_images/574.jpg
#   inflating: semantic_drone_dataset/original_images/576.jpg
#   inflating: semantic_drone_dataset/original_images/579.jpg
#   inflating: semantic_drone_dataset/original_images/580.jpg
#   inflating: semantic_drone_dataset/original_images/582.jpg
#   inflating: semantic_drone_dataset/original_images/583.jpg
#   inflating: semantic_drone_dataset/original_images/584.jpg
#   inflating: semantic_drone_dataset/original_images/585.jpg
#   inflating: semantic_drone_dataset/original_images/586.jpg
#   inflating: semantic_drone_dataset/original_images/587.jpg
#   inflating: semantic_drone_dataset/original_images/588.jpg
#   inflating: semantic_drone_dataset/original_images/590.jpg
#   inflating: semantic_drone_dataset/original_images/591.jpg
#   inflating: semantic_drone_dataset/original_images/592.jpg
#   inflating: semantic_drone_dataset/original_images/593.jpg
#   inflating: semantic_drone_dataset/original_images/594.jpg
#   inflating: semantic_drone_dataset/original_images/596.jpg
#   inflating: semantic_drone_dataset/original_images/598.jpg

# %%
classes = pd.read_csv('/content/class_dict_seg.csv')

# %%
classes
# Out:
#            name    r    g    b
# 0     unlabeled    0    0    0
# 1    paved-area  128   64  128
# 2          dirt  130   76    0
# 3         grass    0  102    0
# 4        gravel  112  103   87
# 5         water   28   42  168
# 6         rocks   48   41   30
# 7          pool    0   50   89
# 8    vegetation  107  142   35
# 9          roof   70   70   70
# 10         wall  102  102  156
# 11       window  254  228   12
# 12         door  254  148   12
# 13        fence  190  153  153
# 14   fence-pole  153  153  153
# 15       person  255   22   96
# 16          dog  102   51    0
# 17          car    9  143  150
# 18      bicycle  119   11   32
# 19         tree   51   51    0
# 20    bald-tree  190  250  190
# 21    ar-marker  112  150  146
# 22     obstacle    2  135  115
# 23  conflicting  255    0    0

# %%
classes_names = classes.name.values.tolist()
print(classes_names)
len(classes_names)
# Out:
# ['unlabeled', 'paved-area', 'dirt', 'grass', 'gravel', 'water', 'rocks', 'pool', 'vegetation', 'roof', 'wall', 'window', 'door', 'fence', 'fence-pole', 'person', 'dog', 'car', 'bicycle', 'tree', 'bald-tree', 'ar-marker', 'obstacle', 'conflicting']
# 24

# %%
plt.figure(figsize = (9, 20))
for n in range(6):
    image = np.array(Image.open(f'/content/semantic_drone_dataset/original_images/00{n}.jpg'))
    label = np.array(Image.open(f'/content/semantic_drone_dataset/label_images_semantic/00{n}.png'))
    plt.subplot(6, 2, 2 * n + 1)
    plt.imshow(image)
    plt.subplot(6, 2, 2 * n + 2)
    plt.imshow(label)

# %%
image.shape, label.shape, image.min(), image.max(), label.min(), label.max()
# Out:
# ((4000, 6000, 3), (4000, 6000), 0, 255, 0, 22)

# %%
nunber_of_classes = 23 
def create_dataset_df():
  original_images = [filenames for _, _, filenames in os.walk('/content/semantic_drone_dataset/original_images')][0]
  original_images.sort()
  label_images_semantic = [filenames for _, _, filenames in os.walk('/content/semantic_drone_dataset/label_images_semantic')][0]
  label_images_semantic.sort()
  return pd.DataFrame({'label_images_semantic': label_images_semantic}, index=original_images)
dataset = create_dataset_df()
print('Total images pairs: ', len(dataset))
# Out:
# Total images pairs:  400

# %%
x_train_and_val, x_test = train_test_split(dataset, test_size=0.1, random_state=13)
x_train, x_val = train_test_split(x_train_and_val, test_size=0.2, random_state=13)
print('Train size -', len(x_train), 'Val size -', len(x_val), 'Test size -', len(x_test))
# Out:
# Train size - 288 Val size - 72 Test size - 40

# %%
class ImageSegmentationDataset(Dataset):
    def __init__(self, original_images, label_images_semantic, sample, mean, std, 
                 transform=None, patch=False):
        self.original_images = original_images
        self.label_images_semantic = label_images_semantic
        self.sample = sample
        self.transform = transform
        self.patches = patch
        self.mean = mean
        self.std = std
        
    def __len__(self):
        return len(self.sample)
    
    def __getitem__(self, idx):
        image = cv2.cvtColor(cv2.imread(self.original_images + 
                                      self.sample.index.values[idx]), cv2.COLOR_BGR2RGB)
        label = cv2.imread(self.label_images_semantic + self.sample.label_images_semantic.values[idx], cv2.IMREAD_GRAYSCALE)
        
        if self.transform is not None:
            aug = self.transform(image=image, mask=label)
            image, label = Image.fromarray(aug['image']), aug['mask']
        
        if self.transform is None:
            image = Image.fromarray(image)
        
        transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(), 
                                            torchvision.transforms.Normalize(self.mean, self.std)])
        image, label = transform(image), torch.from_numpy(label).long()
        
        if self.patches:
            image, label = self.tiles(image, label)
        return image, label
    
    def tiles(self, image, label):

        image_patches = image.unfold(1, 512, 512).unfold(2, 768, 768) 
        image_patches  = image_patches.contiguous().view(3,-1, 512, 768) 
        image_patches = image_patches.permute(1,0,2,3)
        
        label_patches = label.unfold(0, 512, 512).unfold(1, 768, 768)
        label_patches = label_patches.contiguous().view(-1, 512, 768)
        
        return image_patches, label_patches

# %%
mean=[0.485, 0.456, 0.406]
std=[0.229, 0.224, 0.225]

t_train = albumentations.Compose([albumentations.Resize(704, 1056, interpolation=cv2.INTER_NEAREST), 
                                  albumentations.HorizontalFlip(), albumentations.VerticalFlip(), 
                                  albumentations.GridDistortion(p=0.2), albumentations.RandomBrightnessContrast((0,0.5),(0,0.5)),
                                  albumentations.GaussNoise()])

t_val = albumentations.Compose([albumentations.Resize(704, 1056, interpolation=cv2.INTER_NEAREST), 
                                albumentations.HorizontalFlip(),
                                albumentations.GridDistortion(p=0.2)])

train_set = ImageSegmentationDataset('/content/semantic_drone_dataset/original_images/', 
                         '/content/semantic_drone_dataset/label_images_semantic/', x_train, mean, std, t_train, patch=False)
val_set = ImageSegmentationDataset('/content/semantic_drone_dataset/original_images/', 
                         '/content/semantic_drone_dataset/label_images_semantic/', x_val, mean, std, t_val, patch=False)

batch_size= 3 

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## **Models From Pytorch**

# %%
models = {
    'PAN': smp.PAN('mobilenet_v2', encoder_weights='imagenet', classes=23, activation=None),
    #'DeepLabV3': smp.DeepLabV3('mobilenet_v2', encoder_weights='imagenet', classes=23, activation=None),
    #'DeepLabV3Plus': smp.DeepLabV3Plus('mobilenet_v2', encoder_weights='imagenet', classes=23, activation=None)
    }

# %%
def pixel_accuracy(output, label):
    with torch.no_grad():
        output = torch.argmax(torch.nn.functional.softmax(output, dim=1), dim=1)
        correct = torch.eq(output, label).int()
        accuracy = float(correct.sum()) / float(correct.numel())
    return accuracy

# %%
def mIoU(predicted_label, label, smooth=1e-10, number_of_classes=23):
    with torch.no_grad():
        predicted_label = torch.nn.functional.softmax(predicted_label, dim=1)
        predicted_label = torch.argmax(predicted_label, dim=1).contiguous().view(-1)
        label = label.contiguous().view(-1)
        iou_per_class = list()
        for class_number in range(0, number_of_classes):  # loop per pixel class
            predicted_class = predicted_label == class_number
            true_label = label == class_number

            if true_label.long().sum().item() == 0:  # no exist label in this loop
                iou_per_class.append(np.nan)
            else:
                intersect = torch.logical_and(predicted_class, true_label).sum().float().item()
                union = torch.logical_or(predicted_class, true_label).sum().float().item()
                iou_per_class.append((intersect + smooth) / (union + smooth))
        return np.nanmean(iou_per_class)

# %%
def get_learning_rate(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']


def fit(epochs, model, train_loader, val_loader, criterion, optimizer, scheduler, patch=False):
    torch.cuda.empty_cache()
    train_losses, test_losses, val_iou, val_acc, train_iou, train_acc, learning_rates = list(), list(), list(), list(), \
        list(), list(), list()
    min_loss, decrease, not_improve = np.inf, 1, 0

    model.to(device)
    fit_time = time.time()
    for e in range(epochs):
        running_loss, iou_score, accuracy = 0, 0, 0
        model.train()
        for _, data in enumerate(tqdm(train_loader)):
            image_tiles, label_tiles = data
            if patch:
                bs, n_tiles, c, h, w = image_tiles.size()
                image_tiles, label_tiles = image_tiles.view(-1, c, h, w), label_tiles.view(-1, h, w)

            image, label = image_tiles.to(device), label_tiles.to(device)
            output = model(image)
            loss = criterion(output, label)
            iou_score += mIoU(output, label)
            accuracy += pixel_accuracy(output, label)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            learning_rates.append(get_learning_rate(optimizer))
            scheduler.step()
            running_loss += loss.item()
        else:
            model.eval()
            test_loss, test_accuracy, val_iou_score =0, 0, 0
            with torch.no_grad():
                for i, data in enumerate(tqdm(val_loader)):
                    image_tiles, label_tiles = data
                    if patch:
                        bs, n_tiles, c, h, w = image_tiles.size()
                        image_tiles, label_tiles = image_tiles.view(-1, c, h, w), label_tiles.view(-1, h, w)

                    image, label = image_tiles.to(device), label_tiles.to(device);
                    output = model(image)
                    val_iou_score += mIoU(output, label)
                    test_accuracy += pixel_accuracy(output, label)
                    loss = criterion(output, label)
                    test_loss += loss.item()

            # calculatio mean for each batch
            train_losses.append(running_loss / len(train_loader))
            test_losses.append(test_loss / len(val_loader))

            if min_loss > (test_loss / len(val_loader)):
                print('Loss Decreasing.. {:.3f} >> {:.3f} '.format(min_loss, (test_loss / len(val_loader))))
                min_loss = (test_loss / len(val_loader))
                decrease += 1
                if decrease % 5 == 0:
                    print('saving model...')

            if (test_loss / len(val_loader)) > min_loss:
                not_improve += 1
                min_loss = (test_loss / len(val_loader))
                print(f'Loss Not Decrease for {not_improve} time')
                if not_improve == 7:
                    print('Loss not decrease for 7 times, Stop Training')
                    break

            val_iou.append(val_iou_score / len(val_loader))
            train_iou.append(iou_score / len(train_loader))
            train_acc.append(accuracy / len(train_loader))
            val_acc.append(test_accuracy / len(val_loader))
            print("Epoch:{}/{}..".format(e + 1, epochs), "Train Loss: {:.3f}..".format(running_loss / len(train_loader)),
                  "Val Loss: {:.3f}..".format(test_loss / len(val_loader)), "Train mIoU:{:.3f}..".format(iou_score / len(train_loader)),
                  "Val mIoU: {:.3f}..".format(val_iou_score / len(val_loader)), "Train Acc:{:.3f}..".format(accuracy / len(train_loader)),
                  "Val Acc:{:.3f}..".format(test_accuracy / len(val_loader)))
    history = {'train_loss': train_losses, 'val_loss': test_losses, 'train_miou': train_iou, 'val_miou': val_iou,
               'train_acc': train_acc, 'val_acc': val_acc, 'lrs': learning_rates}
    print('Total time: {:.2f} m'.format((time.time() - fit_time) / 60))
    return history

# %%
histories = dict()

# %%
max_lr = 1e-3
epoch = 10
weight_decay = 1e-4
criterion = nn.CrossEntropyLoss()

# %%
for model_name, model in models.items():
  optimizer = torch.optim.AdamW(model.parameters(), lr=max_lr, weight_decay=weight_decay)
  sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epoch,
                                            steps_per_epoch=len(train_loader))
  history = fit(epoch, model, train_loader, val_loader, criterion, optimizer, sched)
  torch.save(model, f'{model_name}.pt')
  histories[model_name] = history
# Out:
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Loss Decreasing.. inf >> 1.295
# Epoch:1/10.. Train Loss: 2.339.. Val Loss: 1.295.. Train mIoU:0.052.. Val mIoU: 0.120.. Train Acc:0.379.. Val Acc:0.641..
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Loss Decreasing.. 1.295 >> 0.961
# Epoch:2/10.. Train Loss: 1.338.. Val Loss: 0.961.. Train mIoU:0.141.. Val mIoU: 0.190.. Train Acc:0.618.. Val Acc:0.722..
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Loss Decreasing.. 0.961 >> 0.765
# Epoch:3/10.. Train Loss: 1.211.. Val Loss: 0.765.. Train mIoU:0.185.. Val mIoU: 0.272.. Train Acc:0.644.. Val Acc:0.772..
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Loss Not Decrease for 1 time
# Epoch:4/10.. Train Loss: 1.050.. Val Loss: 0.828.. Train mIoU:0.226.. Val mIoU: 0.283.. Train Acc:0.677.. Val Acc:0.752..
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Loss Decreasing.. 0.828 >> 0.668
# saving model...
# Epoch:5/10.. Train Loss: 1.024.. Val Loss: 0.668.. Train mIoU:0.240.. Val mIoU: 0.282.. Train Acc:0.689.. Val Acc:0.792..
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Loss Decreasing.. 0.668 >> 0.649
# Epoch:6/10.. Train Loss: 0.939.. Val Loss: 0.649.. Train mIoU:0.272.. Val mIoU: 0.310.. Train Acc:0.708.. Val Acc:0.804..
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Loss Decreasing.. 0.649 >> 0.582
# Epoch:7/10.. Train Loss: 0.832.. Val Loss: 0.582.. Train mIoU:0.297.. Val mIoU: 0.344.. Train Acc:0.743.. Val Acc:0.821..
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Loss Decreasing.. 0.582 >> 0.511
# Epoch:8/10.. Train Loss: 0.752.. Val Loss: 0.511.. Train mIoU:0.325.. Val mIoU: 0.370.. Train Acc:0.768.. Val Acc:0.841..
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Loss Decreasing.. 0.511 >> 0.502
# Epoch:9/10.. Train Loss: 0.698.. Val Loss: 0.502.. Train mIoU:0.337.. Val mIoU: 0.379.. Train Acc:0.781.. Val Acc:0.844..
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# Loss Not Decrease for 2 time
# Epoch:10/10.. Train Loss: 0.673.. Val Loss: 0.520.. Train mIoU:0.356.. Val mIoU: 0.374.. Train Acc:0.790.. Val Acc:0.840..
# Total time: 35.65 m

# %%
def plot_loss(history, model_name):
  fig, (ax1, ax2, ax3)  = plt.subplots(1, 3, figsize=(20, 5))
  ax1.plot(history['val_loss'], label='val', marker='o')
  ax1.plot(history['train_loss'], label='train', marker='o')
  ax1.set(xlabel='epoch', ylabel='loss', title=f'Loss per epoch for {model_name}')

  ax2.plot(history['train_miou'], label='train_mIoU', marker='*')
  ax2.plot(history['val_miou'], label='val_mIoU',  marker='*')
  ax2.set(xlabel='epoch', ylabel='mean IoU', title=f'Score per epoch for {model_name}')

  ax3.plot(history['train_acc'], label='train_accuracy', marker='*')
  ax3.plot(history['val_acc'], label='val_accuracy',  marker='*')
  ax3.set(xlabel='epoch', ylabel='Accuracy', title=f'Accuracy per epoch for {model_name}')
    
  ax1.grid(color='b', alpha=0.5, linestyle='dashed', linewidth=0.5)
  ax2.grid(color='b', alpha=0.5, linestyle='dashed', linewidth=0.5)
  ax3.grid(color='b', alpha=0.5, linestyle='dashed', linewidth=0.5)
  plt.show()

# %%
for model_name, history in histories.items():
  plot_loss(history, model_name)

# %% [markdown]
# ## **Results**

# %%
class DroneTestDataset(Dataset):
    def __init__(self, original_images, label_images_semantic, sample, transform=None):
        self.original_images = original_images
        self.label_images_semantic = label_images_semantic
        self.sample = sample
        self.transform = transform
      
    def __len__(self):
        return len(self.sample)
    
    def __getitem__(self, idx):
        image = cv2.cvtColor(cv2.imread(self.original_images + 
                                      self.sample.index.values[idx]), cv2.COLOR_BGR2RGB)
        label = cv2.imread(self.label_images_semantic + self.sample.label_images_semantic.values[idx], cv2.IMREAD_GRAYSCALE)
        if self.transform is not None:
            aug = self.transform(image=image, mask=label)
            image = Image.fromarray(aug['image'])
            label = aug['mask']
        if self.transform is None:
            image = Image.fromarray(image)
        label = torch.from_numpy(label).long()
        
        return image, label

t_test = albumentations.Resize(768, 1152, interpolation=cv2.INTER_NEAREST)
test_set = DroneTestDataset('/content/semantic_drone_dataset/original_images/', 
                            '/content/semantic_drone_dataset/label_images_semantic/', x_test, transform=t_test)

# %%
def predict_image_label_miou_score_and_accuracy(model, image, label, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]):
    model.eval()
    transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(), torchvision.transforms.Normalize(mean, std)])
    image = transform(image)
    model.to(device); 
    image, label = image.to(device), label.to(device)
    with torch.no_grad():
        image, label = image.unsqueeze(0), label.unsqueeze(0)
        output = model(image)
        score = mIoU(model(image), label)
        accuracy = pixel_accuracy(output, label)
        labeled = torch.argmax(output, dim=1)
        labeled = labeled.cpu().squeeze(0)
    return labeled, score, accuracy

# %%
def get_miou_scores(model, test_set):
    miou_scores = list()
    for pair in tqdm(range(len(test_set))):
        image, label = test_set[pair]
        predicted_label, score, accuracy = predict_image_label_miou_score_and_accuracy(model, image, label)
        miou_scores.append(score)
    return miou_scores

def get_pixel_accuracies(model, test_set):
    accuracies = []
    for i in tqdm(range(len(test_set))):
        image, label = test_set[i]
        predicted_label, score, accuracy = predict_image_label_miou_score_and_accuracy(model, image, label)
        accuracies.append(accuracy)
    return accuracies

# %%
for model_name, model in models.items():
  image, label = test_set[3]
  predicted_label, score, accuracy = predict_image_label_miou_score_and_accuracy(model, image, label)
  miou_score = get_miou_scores(model, test_set)
  accuracy = get_pixel_accuracies(model, test_set)

  fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,10))
  ax1.imshow(image)
  ax1.set_title('Picture');
  ax2.imshow(label)
  ax2.set_title('Ground truth')
  ax2.set_axis_off()
  ax3.imshow(predicted_label)
  ax3.set_title(f'{model_name}' +'| mIoU {:.3f}'.format(score))
  ax3.set_axis_off()
  plt.show()

  print(f'Test Set mIoU for {model_name} :', np.mean(miou_score))
  print(f'Test Set Pixel Accuracy for {model_name} :', np.mean(accuracy))
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
# Test Set mIoU for PAN : 0.3482423622858747
# Test Set Pixel Accuracy for PAN : 0.835208214653863
